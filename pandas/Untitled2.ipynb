# %%
import pandas as pd
df=pd.read_csv('./survey_results_public.csv')
df1=pd.read_csv('./survey_results_schema.csv')

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
df["RemoteWork"].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %%
import plotly.express as px
#гистограмма
fig = px.histogram(df, x='RemoteWork', title='Распределение')
fig.show()
#Круговая диаграмма
fig2=px.pie(df,names="RemoteWork")
fig2.show()

# %%
person={
    "first": "Alex",
    "last": "Shilo",
    "email": "alex.pricker@gmail.com"
}
people={ "first": ["Alex","Serg","Tom"],
    "last": ["Shilo","Vaginsky","JAM"],
        "email": ["alex.pricker@gmail.com","sergvag@yandex.ru","1.1.ru"] }
df= pd.DataFrame(people)

df
# Out:
#   first      last                   email
# 0  Alex     Shilo  alex.pricker@gmail.com
# 1  Serg  Vaginsky       sergvag@yandex.ru
# 2   Tom       JAM                  1.1.ru

# %%
df.loc[[1,2],["email"]]
# Out:
#                email
# 1  sergvag@yandex.ru
# 2             1.1.ru
